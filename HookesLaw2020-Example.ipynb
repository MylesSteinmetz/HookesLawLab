# %% [markdown]
# # Method 1:  Determine k for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
f1 = np.array([.981,1.23,1.47,1.72,1.96,2.21])
x1 = np.array([.33,.41,.49,.57,.65,.74])

f2 = np.array([.981,1.23,1.47,1.72,1.96,2.21])
x2 = np.array([.08,.11,.13,.15,.17,.18])

errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,f1,errm*9.8,'Small k spring','x(m)','F(N)','N/m')

phys.plotfit(x2,f2,errm*9.8,"Large k spring","x(m)","F(N)","N/m")

phys.plotfit(m1,T1,errm,'Large k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 3.01 N/m
# Error in slope = 0.03 N/m
# Goodness of fit = 3.81
# Slope = 12.03 N/m
# Error in slope = 0.12 N/m
# Goodness of fit = 206.92

# %% [markdown]
# # Method 2:  Determine k for spring 1 and 2

# %%
T1 = np.array([1.00,.950,.907,.860,.813,.762])**2
m1 = np.array([.300,.275,.250,.225,.200,.175])

T2 = np.array([1.5,1.39,1.28,1.14,.99,.81])**2
m2 = np.array([.175,.150,.125,.100,.075,.050])


errm = np.array([1,1,1,1,1,1])/1000

phys.plotfit(m1,T1,errm,'Large k spring','m(kg)','T^2(s^2)','N/m')
phys.plotfit(m2,T2,errm,'Small k spring','m(kg)','T^2(s^2)','N/m')
# Out:
# Slope = 3.32 N/m
# Error in slope = 0.01 N/m
# Goodness of fit = 143.18
# Slope = 12.76 N/m
# Error in slope = 0.01 N/m
# Goodness of fit = 495.86
